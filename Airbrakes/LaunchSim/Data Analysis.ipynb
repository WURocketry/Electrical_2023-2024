# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
accelData = np.loadtxt('./AccelReadings.txt',delimiter=',')

# %%
accelData[0:1000,:]
# Out:
# array([[ 0.015625,  0.011719,  0.      ],
#        [-0.023437, -0.027344,  0.      ],
#        [ 0.015625,  0.011719,  0.      ],
#        ...,
#        [ 0.023437,  0.011719,  0.      ],
#        [ 0.015625,  0.011719,  0.035156],
#        [-0.023437,  0.011719,  0.      ]])

# %%
plt.plot(accelData[0:1000,:])

# %%
np.var(accelData)
# Out:
# 0.0003199006901437827

# %% [markdown]
# ## Altitude

# %%
altitudeData = np.loadtxt('./Altitude Readings.txt',delimiter=',')

# %%
altitudeData
# Out:
# array([25.516899, 25.615191, 25.805223, ..., 26.141445, 26.12229 ,
#        26.043653])

# %%
np.var(altitudeData)
# Out:
# 0.008408664942289009
